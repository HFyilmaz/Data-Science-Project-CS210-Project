# %%
import os
import pandas as pd

# Directory containing the CSV files
directory = "chunks_sentiment"

# Initialize an empty list to store the DataFrames
data_frames = []

# Iterate over the CSV files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        # Read each CSV file into a DataFrame
        file_path = os.path.join(directory, filename)
        df = pd.read_csv(file_path)
        
        # Append the DataFrame to the list
        data_frames.append(df)

# Concatenate the DataFrames in the list
df = pd.concat(data_frames, ignore_index=True)

# Write the merged data to a new CSV file
df.to_csv("MAINDATA.csv", index=False)

# %%
df
# Out:
#        Unnamed: 0     channelName
# 0             0.0  Cüneyt Özdemir  \
# 1             1.0  Cüneyt Özdemir
# 2             2.0  Cüneyt Özdemir
# 3             3.0  Cüneyt Özdemir
# 4             4.0  Cüneyt Özdemir
# ...           ...             ...
# 23995      4795.0    Özlem Gürses
# 23996      4796.0    Özlem Gürses
# 23997      4797.0    Özlem Gürses
# 23998      4798.0    Özlem Gürses
# 23999      4799.0    Özlem Gürses
#
#                                              video_title
# 0      İSTANBUL DEPREME HAZIR MI? AFET YÖNETMEYİ NEDE...  \
# 1      DEPREM BÖLGESİNDEKİ TEPKİLER NASIL DİNLENMELİ?...
# 2      ÖLENLER ÖLDÜĞÜ İLE KALDI,YİNE ORTADA SORUMLU YOK!
# 3      YENİ BİR TÜRKİYE VAR! #cuneytozdemir #shorts #fyp
# 4                   ÖZDAĞ'IN DESTEĞİ ZAFER GETİRECEK Mİ?
# ...                                                  ...
# 23995           EN BÜYÜK FELAKET // KAPKARANLIK BİR GECE
# 23996           HATAY’DAYIM, ACI VE DAYANIŞMA BİR ARADA…
# 23997  HDP, KILIÇDAROĞLU İLE DEVAM DEDİ | KONUK : GÜL...
# 23998                  PEKER'DEN VİDEO GELEMEZ, ÇÜNKÜ...
# 23999  “İktidar Değişemez Mi ?” #özlemgürses #haber #...
#
#                                                 sentence
# 0      Eskiden okul bahçelerinde deprem konteynerları...  \
# 1      Yüreklerine, ellerine sağlık 🙏❤️Üzüldüğüm yine...
# 2      devletin sorumluluk sınırı nerede akşam gidip ...
# 3      Be adam deprem hükümetin davasımı yoksa tüm ül...
# 4      10:19 21 ve 24 anayasasının farklarına bakın l...
# ...                                                  ...
# 23995  Özlem hanım , yüreğimiz sesimiz oldunuz sağolu...
# 23996  Özlem hanm biz hatay merkezden kaçtık siz orad...
# 23997  Anaşildi ABD  fetö PKK HDP 6 masa 8srail bir y...
# 23998                               Özlem Gürses\r😍❤❤❤😍😍
# 23999            Değişmesin diye  oy veriyoruz vereceğiz
#
#                 publishDate  sentiment_score
# 0      2023-02-16T21:43:11Z              1.0
# 1      2023-02-17T07:45:10Z              1.0
# 2      2023-03-17T05:51:40Z              1.0
# 3      2023-02-23T06:31:36Z              1.0
# 4      2023-05-24T17:40:48Z              3.0
# ...                     ...              ...
# 23995  2023-02-07T17:57:00Z              1.0
# 23996  2023-02-13T14:52:27Z              1.0
# 23997  2023-05-25T21:49:32Z              1.0
# 23998  2023-03-14T16:29:32Z              5.0
# 23999  2023-05-06T15:05:01Z              1.0
#
# [24000 rows x 6 columns]
